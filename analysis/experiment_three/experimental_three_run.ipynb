# %%
import pandas as pd

def split_and_combine_csv(file_path, chunk_size, metadata_lines=6):
    all_data = []

    # Read the header separately after skipping metadata lines
    with open(file_path, 'r') as f:
        for _ in range(metadata_lines):
            next(f)
        header = next(f).strip().split(',')

    chunk_iter = pd.read_csv(file_path, skiprows=metadata_lines+1, chunksize=chunk_size, header=None, low_memory=False)

    for chunk in chunk_iter:
        chunk.columns = header  # Assign the header to each chunk
        all_data.append(chunk)

    combined_df = pd.concat(all_data, ignore_index=True)
    return combined_df

# Example usage
combined_df = split_and_combine_csv('scenario_three_run.csv', 200000)
combined_df
# Out:
#          "[run number]"  "flow-switch"  "L3-Percent"  "L1-Percent"  \
# 0                     1           True             0          0.12
# 1                     1           True             0          0.12
# 2                     1           True             0          0.12
# 3                     1           True             0          0.12
# 4                     1           True             0          0.12
# ...                 ...            ...           ...           ...
# 3130413              52           True             0          0.12
# 3130414              52           True             0          0.12
# 3130415              52           True             0          0.12
# 3130416              52           True             0          0.12
# 3130417              52           True             0          0.12
#
#          "adjustment"  "lshift"  "L8U-sd"  "L1-logCFU"  "W-logCFU"  "L6-sd"  \
# 0                   4         3         0           -2        1.12     0.12
# 1                   4         3         0           -2        1.12     0.12
# 2                   4         3         0           -2        1.12     0.12
# 3                   4         3         0           -2        1.12     0.12
# 4                   4         3         0           -2        1.12     0.12
# ...               ...       ...       ...          ...         ...      ...
# 3130413             4         3         0           -2        1.12     0.12
# 3130414             4         3         0           -2        1.12     0.12
# 3130415             4         3         0           -2        1.12     0.12
# 3130416             4         3         0           -2        1.12     0.12
# 3130417             4         3         0           -2        1.12     0.12
#
#          ...  "Average-Amount-p-LogCFU-L6-percentage"  \
# 0        ...                                 0.000000
# 1        ...                                 0.000000
# 2        ...                                 0.000000
# 3        ...                                 0.000000
# 4        ...                                 0.000000
# ...      ...                                      ...
# 3130413  ...                                 0.111111
# 3130414  ...                                 0.111111
# 3130415  ...                                 0.111111
# 3130416  ...                                 0.111111
# 3130417  ...                                 0.111111
#
#          "Average-Amount-p-LogCFU-L6"  \
# 0         <RuntimePrimitiveException>
# 1         <RuntimePrimitiveException>
# 2         <RuntimePrimitiveException>
# 3         <RuntimePrimitiveException>
# 4         <RuntimePrimitiveException>
# ...                               ...
# 3130413                             0
# 3130414                             0
# 3130415                             0
# 3130416                             0
# 3130417                             0
#
#          "Average-Amount-p-LogCFU-L7-percentage"  \
# 0                                       0.113636
# 1                                       0.113636
# 2                                       0.113636
# 3                                       0.113636
# 4                                       0.113636
# ...                                          ...
# 3130413                                 0.284091
# 3130414                                 0.284091
# 3130415                                 0.284091
# 3130416                                 0.284091
# 3130417                                 0.284091
#
#          "Average-Amount-p-LogCFU-L7"  \
# 0                             0.10000
# 1                             0.10000
# 2                             0.10000
# 3                             0.10000
# 4                             0.10000
# ...                               ...
# 3130413                       0.09338
# 3130414                       0.09338
# 3130415                       0.09338
# 3130416                       0.09338
# 3130417                       0.09338
#
#          "Average-Amount-p-LogCFU-L8-percentage"  \
# 0                                       0.119792
# 1                                       0.119792
# 2                                       0.119792
# 3                                       0.119792
# 4                                       0.119792
# ...                                          ...
# 3130413                                 0.260417
# 3130414                                 0.260417
# 3130415                                 0.260417
# 3130416                                 0.260417
# 3130417                                 0.260417
#
#          "Average-Amount-p-LogCFU-L8"  \
# 0                            0.100000
# 1                            0.100000
# 2                            0.100000
# 3                            0.100000
# 4                            0.100000
# ...                               ...
# 3130413                      0.024939
# 3130414                      0.024939
# 3130415                      0.024939
# 3130416                      0.024939
# 3130417                      0.024939
#
#          "Average-Amount-p-LogCFU-L9-percentage"  \
# 0                                           0.09
# 1                                           0.09
# 2                                           0.09
# 3                                           0.09
# 4                                           0.09
# ...                                          ...
# 3130413                                     0.23
# 3130414                                     0.23
# 3130415                                     0.23
# 3130416                                     0.23
# 3130417                                     0.23
#
#          "Average-Amount-p-LogCFU-L9"  \
# 0                            0.100000
# 1                            0.100000
# 2                            0.100000
# 3                            0.100000
# 4                            0.100000
# ...                               ...
# 3130413                      0.094475
# 3130414                      0.094475
# 3130415                      0.094475
# 3130416                      0.094475
# 3130417                      0.094475
#
#          "Average-Amount-p-LogCFU-W1-percentage"  "Average-Amount-p-LogCFU-W1"
# 0                                          0.000   <RuntimePrimitiveException>
# 1                                          0.000   <RuntimePrimitiveException>
# 2                                          0.000   <RuntimePrimitiveException>
# 3                                          0.000   <RuntimePrimitiveException>
# 4                                          0.000   <RuntimePrimitiveException>
# ...                                          ...                           ...
# 3130413                                    0.125                           0.1
# 3130414                                    0.125                           0.1
# 3130415                                    0.125                           0.1
# 3130416                                    0.125                           0.1
# 3130417                                    0.125                           0.1
#
# [3130418 rows x 90 columns]

# %%
combined_df
# Out:
#          "[run number]"  "flow-switch"  "L3-Percent"  "L1-Percent"  \
# 0                     1           True             0          0.12
# 1                     1           True             0          0.12
# 2                     1           True             0          0.12
# 3                     1           True             0          0.12
# 4                     1           True             0          0.12
# ...                 ...            ...           ...           ...
# 3130413              52           True             0          0.12
# 3130414              52           True             0          0.12
# 3130415              52           True             0          0.12
# 3130416              52           True             0          0.12
# 3130417              52           True             0          0.12
#
#          "adjustment"  "lshift"  "L8U-sd"  "L1-logCFU"  "W-logCFU"  "L6-sd"  \
# 0                   4         3         0           -2        1.12     0.12
# 1                   4         3         0           -2        1.12     0.12
# 2                   4         3         0           -2        1.12     0.12
# 3                   4         3         0           -2        1.12     0.12
# 4                   4         3         0           -2        1.12     0.12
# ...               ...       ...       ...          ...         ...      ...
# 3130413             4         3         0           -2        1.12     0.12
# 3130414             4         3         0           -2        1.12     0.12
# 3130415             4         3         0           -2        1.12     0.12
# 3130416             4         3         0           -2        1.12     0.12
# 3130417             4         3         0           -2        1.12     0.12
#
#          ...  "Average-Amount-p-LogCFU-L6-percentage"  \
# 0        ...                                 0.000000
# 1        ...                                 0.000000
# 2        ...                                 0.000000
# 3        ...                                 0.000000
# 4        ...                                 0.000000
# ...      ...                                      ...
# 3130413  ...                                 0.111111
# 3130414  ...                                 0.111111
# 3130415  ...                                 0.111111
# 3130416  ...                                 0.111111
# 3130417  ...                                 0.111111
#
#          "Average-Amount-p-LogCFU-L6"  \
# 0         <RuntimePrimitiveException>
# 1         <RuntimePrimitiveException>
# 2         <RuntimePrimitiveException>
# 3         <RuntimePrimitiveException>
# 4         <RuntimePrimitiveException>
# ...                               ...
# 3130413                             0
# 3130414                             0
# 3130415                             0
# 3130416                             0
# 3130417                             0
#
#          "Average-Amount-p-LogCFU-L7-percentage"  \
# 0                                       0.113636
# 1                                       0.113636
# 2                                       0.113636
# 3                                       0.113636
# 4                                       0.113636
# ...                                          ...
# 3130413                                 0.284091
# 3130414                                 0.284091
# 3130415                                 0.284091
# 3130416                                 0.284091
# 3130417                                 0.284091
#
#          "Average-Amount-p-LogCFU-L7"  \
# 0                             0.10000
# 1                             0.10000
# 2                             0.10000
# 3                             0.10000
# 4                             0.10000
# ...                               ...
# 3130413                       0.09338
# 3130414                       0.09338
# 3130415                       0.09338
# 3130416                       0.09338
# 3130417                       0.09338
#
#          "Average-Amount-p-LogCFU-L8-percentage"  \
# 0                                       0.119792
# 1                                       0.119792
# 2                                       0.119792
# 3                                       0.119792
# 4                                       0.119792
# ...                                          ...
# 3130413                                 0.260417
# 3130414                                 0.260417
# 3130415                                 0.260417
# 3130416                                 0.260417
# 3130417                                 0.260417
#
#          "Average-Amount-p-LogCFU-L8"  \
# 0                            0.100000
# 1                            0.100000
# 2                            0.100000
# 3                            0.100000
# 4                            0.100000
# ...                               ...
# 3130413                      0.024939
# 3130414                      0.024939
# 3130415                      0.024939
# 3130416                      0.024939
# 3130417                      0.024939
#
#          "Average-Amount-p-LogCFU-L9-percentage"  \
# 0                                           0.09
# 1                                           0.09
# 2                                           0.09
# 3                                           0.09
# 4                                           0.09
# ...                                          ...
# 3130413                                     0.23
# 3130414                                     0.23
# 3130415                                     0.23
# 3130416                                     0.23
# 3130417                                     0.23
#
#          "Average-Amount-p-LogCFU-L9"  \
# 0                            0.100000
# 1                            0.100000
# 2                            0.100000
# 3                            0.100000
# 4                            0.100000
# ...                               ...
# 3130413                      0.094475
# 3130414                      0.094475
# 3130415                      0.094475
# 3130416                      0.094475
# 3130417                      0.094475
#
#          "Average-Amount-p-LogCFU-W1-percentage"  "Average-Amount-p-LogCFU-W1"
# 0                                          0.000   <RuntimePrimitiveException>
# 1                                          0.000   <RuntimePrimitiveException>
# 2                                          0.000   <RuntimePrimitiveException>
# 3                                          0.000   <RuntimePrimitiveException>
# 4                                          0.000   <RuntimePrimitiveException>
# ...                                          ...                           ...
# 3130413                                    0.125                           0.1
# 3130414                                    0.125                           0.1
# 3130415                                    0.125                           0.1
# 3130416                                    0.125                           0.1
# 3130417                                    0.125                           0.1
#
# [3130418 rows x 90 columns]

# %%
combined_df.columns = [ eval(i) for i in combined_df.columns ]

# %%
good_data = combined_df[[ '[run number]',
                'Detection-Limit',
                'global-percent', 'global-logCFU', 'global-sd',
                'initial_contaminated','avocado-counter',
                'probality-Of-Contamination','Contamination-Level','SD',
                'initial_batch_contaminated',
                'pfactor', '[step]','enter_processing_list']]
good_data
# Out:
#          [run number]  Detection-Limit  global-percent  global-logCFU  \
# 0                   1             0.04             0.1            0.1
# 1                   1             0.04             0.1            0.1
# 2                   1             0.04             0.1            0.1
# 3                   1             0.04             0.1            0.1
# 4                   1             0.04             0.1            0.1
# ...               ...              ...             ...            ...
# 3130413            52             0.04             0.1            0.1
# 3130414            52             0.04             0.1            0.1
# 3130415            52             0.04             0.1            0.1
# 3130416            52             0.04             0.1            0.1
# 3130417            52             0.04             0.1            0.1
#
#          global-sd  initial_contaminated  avocado-counter  \
# 0                0                     0                0
# 1                0                     1                2
# 2                0                     2                4
# 3                0                     3                6
# 4                0                     3                8
# ...            ...                   ...              ...
# 3130413          0                  4209            60000
# 3130414          0                  4209            60000
# 3130415          0                  4209            60000
# 3130416          0                  4209            60000
# 3130417          0                  4209            60000
#
#          probality-Of-Contamination  Contamination-Level  SD  \
# 0                               0.2                  0.1   0
# 1                               0.2                  0.1   0
# 2                               0.2                  0.1   0
# 3                               0.2                  0.1   0
# 4                               0.2                  0.1   0
# ...                             ...                  ...  ..
# 3130413                         0.7                  0.1   0
# 3130414                         0.7                  0.1   0
# 3130415                         0.7                  0.1   0
# 3130416                         0.7                  0.1   0
# 3130417                         0.7                  0.1   0
#
#          initial_batch_contaminated  pfactor  [step]  \
# 0                               0.1        1       0
# 1                               0.1        1       1
# 2                               0.1        1       2
# 3                               0.1        1       3
# 4                               0.1        1       4
# ...                             ...      ...     ...
# 3130413                         0.1        1   60242
# 3130414                         0.1        1   60243
# 3130415                         0.1        1   60244
# 3130416                         0.1        1   60245
# 3130417                         0.1        1   60246
#
#                                      enter_processing_list
# 0                                                       []
# 1                                                       []
# 2                                                       []
# 3                                                       []
# 4                                                       []
# ...                                                    ...
# 3130413  [[1 119.625 0.912996807455461 -0.0395307410931...
# 3130414  [[1 119.625 0.912996807455461 -0.0395307410931...
# 3130415  [[1 119.625 0.912996807455461 -0.0395307410931...
# 3130416  [[1 119.625 0.912996807455461 -0.0395307410931...
# 3130417  [[1 119.625 0.912996807455461 -0.0395307410931...
#
# [3130418 rows x 14 columns]

# %%
good_data.columns = ['[run number]', 'Detection-Limit', 'contaminated_surface_percent', 'contaminated_surface_logCFU',
       'contaminated_surface_sd', 'initial_contaminated_avocado_counter', 'avocado-counter_total',
       'probality-Of-Contamination_for_avocado', 'Contamination-Level_avocado_logCFU', 'avocado_SD',
       'percentage_of_batch_initial_contaminated', 'pfactor_for_surface_ratio','steps','enter_processing_list']

# %%
def split_to_columns(x):
    return x[2:-2].split("] [")

def process_list(lst):
    return [i for i in lst] 

def split_string(x):
    return x.split(" ")

def combine_data_frame(x):
    return pd.concat([x, pd.DataFrame(x.Output_packed.tolist(), 
                                      index=x.index,
                                      columns=["Process_ID", "Time_In_Seconds","CFU","logCFU",
                                       "Handler", "Processed_Crates","Safety_Status","Patch_Contamination"])], axis=1)

def data_filtering(df):
    # df = df.drop("Output_packed",axis=1)
    df = df[df.enter_processing_list.apply(lambda x: len(x) > 3)]
    df = df.drop_duplicates("enter_processing_list")
    df.enter_processing_list = df.enter_processing_list.apply(split_to_columns)

    df = df.explode('enter_processing_list')
    df.enter_processing_list = df.enter_processing_list.apply(split_string)
    df = df.rename(columns={'enter_processing_list': 'Output_packed'})
    df = df.reset_index(drop=True)
    df = combine_data_frame(df)
    df = df.drop("Patch_Contamination",axis=1)
    return df

output = data_filtering(good_data)
output
# Out:
#         [run number]  Detection-Limit  contaminated_surface_percent  \
# 0                  1             0.04                           0.1
# 1                  1             0.04                           0.1
# 2                  1             0.04                           0.1
# 3                  1             0.04                           0.1
# 4                  1             0.04                           0.1
# ...              ...              ...                           ...
# 155787            52             0.04                           0.1
# 155788            52             0.04                           0.1
# 155789            52             0.04                           0.1
# 155790            52             0.04                           0.1
# 155791            52             0.04                           0.1
#
#         contaminated_surface_logCFU  contaminated_surface_sd  \
# 0                               0.1                        0
# 1                               0.1                        0
# 2                               0.1                        0
# 3                               0.1                        0
# 4                               0.1                        0
# ...                             ...                      ...
# 155787                          0.1                        0
# 155788                          0.1                        0
# 155789                          0.1                        0
# 155790                          0.1                        0
# 155791                          0.1                        0
#
#         initial_contaminated_avocado_counter  avocado-counter_total  \
# 0                                       1217                  60000
# 1                                       1217                  60000
# 2                                       1217                  60000
# 3                                       1217                  60000
# 4                                       1217                  60000
# ...                                      ...                    ...
# 155787                                  4209                  60000
# 155788                                  4209                  60000
# 155789                                  4209                  60000
# 155790                                  4209                  60000
# 155791                                  4209                  60000
#
#         probality-Of-Contamination_for_avocado  \
# 0                                          0.2
# 1                                          0.2
# 2                                          0.2
# 3                                          0.2
# 4                                          0.2
# ...                                        ...
# 155787                                     0.7
# 155788                                     0.7
# 155789                                     0.7
# 155790                                     0.7
# 155791                                     0.7
#
#         Contamination-Level_avocado_logCFU  avocado_SD  ...  \
# 0                                      0.1           0  ...
# 1                                      0.1           0  ...
# 2                                      0.1           0  ...
# 3                                      0.1           0  ...
# 4                                      0.1           0  ...
# ...                                    ...         ...  ...
# 155787                                 0.1           0  ...
# 155788                                 0.1           0  ...
# 155789                                 0.1           0  ...
# 155790                                 0.1           0  ...
# 155791                                 0.1           0  ...
#
#         pfactor_for_surface_ratio  steps  \
# 0                               1  60251
# 1                               1  60251
# 2                               1  60251
# 3                               1  60251
# 4                               1  60251
# ...                           ...    ...
# 155787                          1  60242
# 155788                          1  60242
# 155789                          1  60242
# 155790                          1  60242
# 155791                          1  60242
#
#                                             Output_packed Process_ID  \
# 0       [1, 121.25, 0.20794644113910307, -0.6820485078...          1
# 1       [2, 122, 0.4082898038465691, -0.38903146550551...          2
# 2       [3, 122.875, 0.2668762972061712, -0.5736899966...          3
# 3       [4, 123.5, 0.2797107253597671, -0.553290880517...          4
# 4       [5, 125.625, 0.27126178231745235, -0.566611389...          5
# ...                                                   ...        ...
# 155787  [2993, 7396.375, 0.01810901205827969, -1.74210...       2993
# 155788  [2994, 7397.625, 0.019902174116808072, -1.7010...       2994
# 155789  [2995, 7400, 0.02151965832455098, -1.667164628...       2995
# 155790  [2996, 7401.75, 0.020104721137361288, -1.69670...       2996
# 155791  [2997, 7403.875, 0.0156554359870688, -1.805334...       2997
#
#        Time_In_Seconds                   CFU               logCFU  \
# 0               121.25   0.20794644113910307  -0.6820485078880123
# 1                  122    0.4082898038465691   -0.389031465505518
# 2              122.875    0.2668762972061712  -0.5736899966496818
# 3                123.5    0.2797107253597671  -0.5532908805170728
# 4              125.625   0.27126178231745235  -0.5666113890537438
# ...                ...                   ...                  ...
# 155787        7396.375   0.01810901205827969   -1.742105242084673
# 155788        7397.625  0.019902174116808072  -1.7010994785974178
# 155789            7400   0.02151965832455098  -1.6671646284024935
# 155790         7401.75  0.020104721137361288  -1.6967019464031547
# 155791        7403.875    0.0156554359870688  -1.8053348332440262
#
#                                               Handler Processed_Crates  \
# 0            packaging_location_surface_crate_up_four                1
# 1         packaging_location_surface_crate_bottom_one                1
# 2         packaging_location_surface_crate_bottom_two                1
# 3           packaging_location_surface_crate_up_three                1
# 4        packaging_location_surface_crate_bottom_four                1
# ...                                               ...              ...
# 155787  packaging_location_surface_crate_bottom_three              379
# 155788        packaging_location_surface_crate_up_two              370
# 155789    packaging_location_surface_crate_bottom_two              378
# 155790       packaging_location_surface_crate_up_four              374
# 155791   packaging_location_surface_crate_bottom_four              376
#
#        Safety_Status
# 0       contaminated
# 1       contaminated
# 2       contaminated
# 3       contaminated
# 4       contaminated
# ...              ...
# 155787          safe
# 155788          safe
# 155789          safe
# 155790          safe
# 155791          safe
#
# [155792 rows x 21 columns]

# %%
len(output[output["[run number]"] == 1])
# Out:
# 2997

# %%
output.to_csv("experiment_three_results.csv")
